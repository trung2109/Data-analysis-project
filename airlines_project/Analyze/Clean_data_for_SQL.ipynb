# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('airlines_reviews.csv')
df
# Out:
#                                      Title              Name Review Date  \
# 0                       Flight was amazing  Alison Soetantyo  2024-03-01
# 1     seats on this aircraft are dreadful      Robert Watson  2024-02-21
# 2             Food was plentiful and tasty             S Han  2024-02-20
# 3             “how much food was available          D Laynes  2024-02-19
# 4          “service was consistently good”         A Othman   2024-02-19
# ...                                    ...               ...         ...
# 8095                  an uneventful flight         N Vickers  2016-06-20
# 8096           Korean Air always impresses      Kim Holloway  2016-06-12
# 8097                 didn’t offer anything           C Clark  2016-06-06
# 8098       appreciated the service onboard           E Petan  2016-04-21
# 8099              genuinely friendly staff           D Lanor  2016-04-12
#
#                  Airline Verified  \
# 0     Singapore Airlines     True
# 1     Singapore Airlines     True
# 2     Singapore Airlines     True
# 3     Singapore Airlines     True
# 4     Singapore Airlines     True
# ...                  ...      ...
# 8095          Korean Air     True
# 8096          Korean Air    False
# 8097          Korean Air     True
# 8098          Korean Air    False
# 8099          Korean Air    False
#
#                                                 Reviews Type of Traveller  \
# 0       Flight was amazing. The crew onboard this fl...      Solo Leisure
# 1       Booking an emergency exit seat still meant h...      Solo Leisure
# 2       Excellent performance on all fronts. I would...    Family Leisure
# 3      Pretty comfortable flight considering I was f...      Solo Leisure
# 4      The service was consistently good from start ...    Family Leisure
# ...                                                 ...               ...
# 8095    KE124, Brisbane to Incheon (A330) and KE867,...          Business
# 8096    Our recent flight was our fourth trip to the...    Couple Leisure
# 8097    I flew Korean Air from Bali to Seoul in Pres...          Business
# 8098    Seoul to Paris with Korean Air. I am traveli...          Business
# 8099    The 13 hour flight in Business class from Se...          Business
#
#         Month Flown                         Route           Class  \
# 0     December 2023          Jakarta to Singapore  Business Class
# 1     February 2024           Phuket to Singapore   Economy Class
# 2     February 2024        Siem Reap to Singapore   Economy Class
# 3     February 2024  Singapore to London Heathrow   Economy Class
# 4     February 2024       Singapore to Phnom Penh   Economy Class
# ...             ...                           ...             ...
# 8095      June 2016            BNE to ULN via ICN   Economy Class
# 8096      June 2016            SYD to LHR via ICN   Economy Class
# 8097     April 2016                    DPS to ICN  Business Class
# 8098     April 2016                    ICN to CDG  Business Class
# 8099     April 2016                    ICN to YYZ  Business Class
#
#       Seat Comfort  Staff Service  Food & Beverages  Inflight Entertainment  \
# 0                4              4                 4                       4
# 1                5              3                 4                       4
# 2                1              5                 2                       1
# 3                5              5                 5                       5
# 4                5              5                 5                       5
# ...            ...            ...               ...                     ...
# 8095             5              4                 5                       3
# 8096             3              5                 5                       4
# 8097             4              5                 5                       5
# 8098             5              1                 3                       4
# 8099             3              5                 3                       3
#
#       Value For Money  Overall Rating Recommended
# 0                   4               9         yes
# 1                   1               3          no
# 2                   5              10         yes
# 3                   5              10         yes
# 4                   5              10         yes
# ...               ...             ...         ...
# 8095                4               7         yes
# 8096                5              10         yes
# 8097                1               2          no
# 8098                5              10         yes
# 8099                5              10         yes
#
# [8100 rows x 17 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8100 entries, 0 to 8099
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   8100 non-null   object
#  1   Name                    8100 non-null   object
#  2   Review Date             8100 non-null   object
#  3   Airline                 8100 non-null   object
#  4   Verified                8100 non-null   object
#  5   Reviews                 8100 non-null   object
#  6   Type of Traveller       8100 non-null   object
#  7   Month Flown             8100 non-null   object
#  8   Route                   8100 non-null   object
#  9   Class                   8100 non-null   object
#  10  Seat Comfort            8100 non-null   int64
#  11  Staff Service           8100 non-null   int64
#  12  Food & Beverages        8100 non-null   int64
#  13  Inflight Entertainment  8100 non-null   int64
#  14  Value For Money         8100 non-null   int64
#  15  Overall Rating          8100 non-null   int64
#  16  Recommended             8100 non-null   object
# dtypes: int64(6), object(11)
# memory usage: 1.1+ MB

# %%
df.isna().sum()
# Out:
# Title                     0
# Name                      0
# Review Date               0
# Airline                   0
# Verified                  0
# Reviews                   0
# Type of Traveller         0
# Month Flown               0
# Route                     0
# Class                     0
# Seat Comfort              0
# Staff Service             0
# Food & Beverages          0
# Inflight Entertainment    0
# Value For Money           0
# Overall Rating            0
# Recommended               0
# dtype: int64

# %%
df['Verified'].value_counts()
# Out:
# Verified
# True                                                                                                                                                                                                                                           6216
# False                                                                                                                                                                                                                                          1881
# *Unverified*                                                                                                                                                                                                                                      1
# NotVerified                                                                                                                                                                                                                                       1
# we do appreciate you bringing this matter to our attention. Please accept my apologies for not having met your expectations; I do hope that we can leave you and your family with a more positive impression on your future flights with us       1
# Name: count, dtype: int64

# %%
df = df[df['Verified'] == 'True']

# %%
df
# Out:
#                                      Title              Name Review Date  \
# 0                       Flight was amazing  Alison Soetantyo  2024-03-01
# 1     seats on this aircraft are dreadful      Robert Watson  2024-02-21
# 2             Food was plentiful and tasty             S Han  2024-02-20
# 3             “how much food was available          D Laynes  2024-02-19
# 4          “service was consistently good”         A Othman   2024-02-19
# ...                                    ...               ...         ...
# 8085               the worst Asian airline          G Nazano  2016-09-21
# 8086         I felt like a valued customer        V Anderson  2016-09-19
# 8093  I was satisfied with the performance             F Lee  2016-07-09
# 8095                  an uneventful flight         N Vickers  2016-06-20
# 8097                 didn’t offer anything           C Clark  2016-06-06
#
#                  Airline Verified  \
# 0     Singapore Airlines     True
# 1     Singapore Airlines     True
# 2     Singapore Airlines     True
# 3     Singapore Airlines     True
# 4     Singapore Airlines     True
# ...                  ...      ...
# 8085          Korean Air     True
# 8086          Korean Air     True
# 8093          Korean Air     True
# 8095          Korean Air     True
# 8097          Korean Air     True
#
#                                                 Reviews Type of Traveller  \
# 0       Flight was amazing. The crew onboard this fl...      Solo Leisure
# 1       Booking an emergency exit seat still meant h...      Solo Leisure
# 2       Excellent performance on all fronts. I would...    Family Leisure
# 3      Pretty comfortable flight considering I was f...      Solo Leisure
# 4      The service was consistently good from start ...    Family Leisure
# ...                                                 ...               ...
# 8085    New York JFK to Tashkent via Seoul Incheon. ...          Business
# 8086    First time flying out of the country from Sa...      Solo Leisure
# 8093   Flown from Seattle to Incheon and then Incheo...      Solo Leisure
# 8095    KE124, Brisbane to Incheon (A330) and KE867,...          Business
# 8097    I flew Korean Air from Bali to Seoul in Pres...          Business
#
#          Month Flown                         Route           Class  \
# 0      December 2023          Jakarta to Singapore  Business Class
# 1      February 2024           Phuket to Singapore   Economy Class
# 2      February 2024        Siem Reap to Singapore   Economy Class
# 3      February 2024  Singapore to London Heathrow   Economy Class
# 4      February 2024       Singapore to Phnom Penh   Economy Class
# ...              ...                           ...             ...
# 8085  September 2016            JFK to TAS via ICN  Business Class
# 8086  September 2016                    SFO to ICN   Economy Class
# 8093       July 2016            SEA to SIN via ICN   Economy Class
# 8095       June 2016            BNE to ULN via ICN   Economy Class
# 8097      April 2016                    DPS to ICN  Business Class
#
#       Seat Comfort  Staff Service  Food & Beverages  Inflight Entertainment  \
# 0                4              4                 4                       4
# 1                5              3                 4                       4
# 2                1              5                 2                       1
# 3                5              5                 5                       5
# 4                5              5                 5                       5
# ...            ...            ...               ...                     ...
# 8085             4              5                 3                       4
# 8086             4              5                 4                       4
# 8093             3              4                 5                       4
# 8095             5              4                 5                       3
# 8097             4              5                 5                       5
#
#       Value For Money  Overall Rating Recommended
# 0                   4               9         yes
# 1                   1               3          no
# 2                   5              10         yes
# 3                   5              10         yes
# 4                   5              10         yes
# ...               ...             ...         ...
# 8085                1               1          no
# 8086                5              10         yes
# 8093                3               7         yes
# 8095                4               7         yes
# 8097                1               2          no
#
# [6216 rows x 17 columns]

# %%
df['Type of Traveller'].value_counts()
# Out:
# Type of Traveller
# Solo Leisure      2535
# Couple Leisure    1442
# Family Leisure    1154
# Business          1085
# Name: count, dtype: int64

# %%
df['Month Flown'].value_counts()
# Out:
# Month Flown
# December 2017    134
# December 2019    129
# January 2018     126
# August 2018      123
# January 2019     123
#                 ...
# May 2014           1
# March 2013         1
# March 2024         1
# May 2015           1
# October 2015       1
# Name: count, Length: 106, dtype: int64

# %%
df['Route'].value_counts()
# Out:
# Route
# London to Singapore                19
# Bangkok to Hong Kong               18
# Bangkok to Singapore               16
# Istanbul to London                 16
# Perth to Singapore                 15
#                                    ..
# Delhi to Nairobi via Dubai          1
# Los Angeles to Tehran via Dubai     1
# Dubai to Milan                      1
# Orlando to Cairo via Dubai          1
# DPS to ICN                          1
# Name: count, Length: 4411, dtype: int64

# %%
df
# Out:
#                                      Title              Name Review Date  \
# 0                       Flight was amazing  Alison Soetantyo  2024-03-01
# 1     seats on this aircraft are dreadful      Robert Watson  2024-02-21
# 2             Food was plentiful and tasty             S Han  2024-02-20
# 3             “how much food was available          D Laynes  2024-02-19
# 4          “service was consistently good”         A Othman   2024-02-19
# ...                                    ...               ...         ...
# 8085               the worst Asian airline          G Nazano  2016-09-21
# 8086         I felt like a valued customer        V Anderson  2016-09-19
# 8093  I was satisfied with the performance             F Lee  2016-07-09
# 8095                  an uneventful flight         N Vickers  2016-06-20
# 8097                 didn’t offer anything           C Clark  2016-06-06
#
#                  Airline Verified  \
# 0     Singapore Airlines     True
# 1     Singapore Airlines     True
# 2     Singapore Airlines     True
# 3     Singapore Airlines     True
# 4     Singapore Airlines     True
# ...                  ...      ...
# 8085          Korean Air     True
# 8086          Korean Air     True
# 8093          Korean Air     True
# 8095          Korean Air     True
# 8097          Korean Air     True
#
#                                                 Reviews Type of Traveller  \
# 0       Flight was amazing. The crew onboard this fl...      Solo Leisure
# 1       Booking an emergency exit seat still meant h...      Solo Leisure
# 2       Excellent performance on all fronts. I would...    Family Leisure
# 3      Pretty comfortable flight considering I was f...      Solo Leisure
# 4      The service was consistently good from start ...    Family Leisure
# ...                                                 ...               ...
# 8085    New York JFK to Tashkent via Seoul Incheon. ...          Business
# 8086    First time flying out of the country from Sa...      Solo Leisure
# 8093   Flown from Seattle to Incheon and then Incheo...      Solo Leisure
# 8095    KE124, Brisbane to Incheon (A330) and KE867,...          Business
# 8097    I flew Korean Air from Bali to Seoul in Pres...          Business
#
#          Month Flown                         Route           Class  \
# 0      December 2023          Jakarta to Singapore  Business Class
# 1      February 2024           Phuket to Singapore   Economy Class
# 2      February 2024        Siem Reap to Singapore   Economy Class
# 3      February 2024  Singapore to London Heathrow   Economy Class
# 4      February 2024       Singapore to Phnom Penh   Economy Class
# ...              ...                           ...             ...
# 8085  September 2016            JFK to TAS via ICN  Business Class
# 8086  September 2016                    SFO to ICN   Economy Class
# 8093       July 2016            SEA to SIN via ICN   Economy Class
# 8095       June 2016            BNE to ULN via ICN   Economy Class
# 8097      April 2016                    DPS to ICN  Business Class
#
#       Seat Comfort  Staff Service  Food & Beverages  Inflight Entertainment  \
# 0                4              4                 4                       4
# 1                5              3                 4                       4
# 2                1              5                 2                       1
# 3                5              5                 5                       5
# 4                5              5                 5                       5
# ...            ...            ...               ...                     ...
# 8085             4              5                 3                       4
# 8086             4              5                 4                       4
# 8093             3              4                 5                       4
# 8095             5              4                 5                       3
# 8097             4              5                 5                       5
#
#       Value For Money  Overall Rating Recommended
# 0                   4               9         yes
# 1                   1               3          no
# 2                   5              10         yes
# 3                   5              10         yes
# 4                   5              10         yes
# ...               ...             ...         ...
# 8085                1               1          no
# 8086                5              10         yes
# 8093                3               7         yes
# 8095                4               7         yes
# 8097                1               2          no
#
# [6216 rows x 17 columns]

# %%
df['Class'].value_counts()
# Out:
# Class
# Economy Class      4238
# Business Class     1610
# Premium Economy     281
# First Class          87
# Name: count, dtype: int64

# %%
df['Recommended'].value_counts()
# Out:
# Recommended
# yes    3241
# no     2975
# Name: count, dtype: int64

# %%
df = df.drop(columns = 'Verified',axis = 1)
df = df.drop(columns = 'Reviews',axis = 1)
df = df.drop(columns = 'Review Date',axis = 1)
df = df.drop(columns = 'Title',axis = 1)

# %%
df
# Out:
#                   Name             Airline Type of Traveller     Month Flown  \
# 0     Alison Soetantyo  Singapore Airlines      Solo Leisure   December 2023
# 1        Robert Watson  Singapore Airlines      Solo Leisure   February 2024
# 2                S Han  Singapore Airlines    Family Leisure   February 2024
# 3             D Laynes  Singapore Airlines      Solo Leisure   February 2024
# 4            A Othman   Singapore Airlines    Family Leisure   February 2024
# ...                ...                 ...               ...             ...
# 8085          G Nazano          Korean Air          Business  September 2016
# 8086        V Anderson          Korean Air      Solo Leisure  September 2016
# 8093             F Lee          Korean Air      Solo Leisure       July 2016
# 8095         N Vickers          Korean Air          Business       June 2016
# 8097           C Clark          Korean Air          Business      April 2016
#
#                              Route           Class  Seat Comfort  \
# 0             Jakarta to Singapore  Business Class             4
# 1              Phuket to Singapore   Economy Class             5
# 2           Siem Reap to Singapore   Economy Class             1
# 3     Singapore to London Heathrow   Economy Class             5
# 4          Singapore to Phnom Penh   Economy Class             5
# ...                            ...             ...           ...
# 8085            JFK to TAS via ICN  Business Class             4
# 8086                    SFO to ICN   Economy Class             4
# 8093            SEA to SIN via ICN   Economy Class             3
# 8095            BNE to ULN via ICN   Economy Class             5
# 8097                    DPS to ICN  Business Class             4
#
#       Staff Service  Food & Beverages  Inflight Entertainment  \
# 0                 4                 4                       4
# 1                 3                 4                       4
# 2                 5                 2                       1
# 3                 5                 5                       5
# 4                 5                 5                       5
# ...             ...               ...                     ...
# 8085              5                 3                       4
# 8086              5                 4                       4
# 8093              4                 5                       4
# 8095              4                 5                       3
# 8097              5                 5                       5
#
#       Value For Money  Overall Rating Recommended
# 0                   4               9         yes
# 1                   1               3          no
# 2                   5              10         yes
# 3                   5              10         yes
# 4                   5              10         yes
# ...               ...             ...         ...
# 8085                1               1          no
# 8086                5              10         yes
# 8093                3               7         yes
# 8095                4               7         yes
# 8097                1               2          no
#
# [6216 rows x 13 columns]

# %%
df[['FromTo','Via']] = df['Route'].str.split(' via ', expand=True)

# %%
df[['From','To']] = df['FromTo'].str.split(' to ', expand=True)

# %%
df[['Month','Year']] = df['Month Flown'].str.split(' ', expand=True)

df
# Out:
#                   Name             Airline Type of Traveller     Month Flown  \
# 0     Alison Soetantyo  Singapore Airlines      Solo Leisure   December 2023
# 1        Robert Watson  Singapore Airlines      Solo Leisure   February 2024
# 2                S Han  Singapore Airlines    Family Leisure   February 2024
# 3             D Laynes  Singapore Airlines      Solo Leisure   February 2024
# 4            A Othman   Singapore Airlines    Family Leisure   February 2024
# ...                ...                 ...               ...             ...
# 8085          G Nazano          Korean Air          Business  September 2016
# 8086        V Anderson          Korean Air      Solo Leisure  September 2016
# 8093             F Lee          Korean Air      Solo Leisure       July 2016
# 8095         N Vickers          Korean Air          Business       June 2016
# 8097           C Clark          Korean Air          Business      April 2016
#
#                              Route           Class  Seat Comfort  \
# 0             Jakarta to Singapore  Business Class             4
# 1              Phuket to Singapore   Economy Class             5
# 2           Siem Reap to Singapore   Economy Class             1
# 3     Singapore to London Heathrow   Economy Class             5
# 4          Singapore to Phnom Penh   Economy Class             5
# ...                            ...             ...           ...
# 8085            JFK to TAS via ICN  Business Class             4
# 8086                    SFO to ICN   Economy Class             4
# 8093            SEA to SIN via ICN   Economy Class             3
# 8095            BNE to ULN via ICN   Economy Class             5
# 8097                    DPS to ICN  Business Class             4
#
#       Staff Service  Food & Beverages  Inflight Entertainment  \
# 0                 4                 4                       4
# 1                 3                 4                       4
# 2                 5                 2                       1
# 3                 5                 5                       5
# 4                 5                 5                       5
# ...             ...               ...                     ...
# 8085              5                 3                       4
# 8086              5                 4                       4
# 8093              4                 5                       4
# 8095              4                 5                       3
# 8097              5                 5                       5
#
#       Value For Money  Overall Rating Recommended  \
# 0                   4               9         yes
# 1                   1               3          no
# 2                   5              10         yes
# 3                   5              10         yes
# 4                   5              10         yes
# ...               ...             ...         ...
# 8085                1               1          no
# 8086                5              10         yes
# 8093                3               7         yes
# 8095                4               7         yes
# 8097                1               2          no
#
#                             FromTo   Via       From               To  \
# 0             Jakarta to Singapore  None    Jakarta        Singapore
# 1              Phuket to Singapore  None     Phuket        Singapore
# 2           Siem Reap to Singapore  None  Siem Reap        Singapore
# 3     Singapore to London Heathrow  None  Singapore  London Heathrow
# 4          Singapore to Phnom Penh  None  Singapore       Phnom Penh
# ...                            ...   ...        ...              ...
# 8085                    JFK to TAS   ICN        JFK              TAS
# 8086                    SFO to ICN  None        SFO              ICN
# 8093                    SEA to SIN   ICN        SEA              SIN
# 8095                    BNE to ULN   ICN        BNE              ULN
# 8097                    DPS to ICN  None        DPS              ICN
#
#           Month  Year
# 0      December  2023
# 1      February  2024
# 2      February  2024
# 3      February  2024
# 4      February  2024
# ...         ...   ...
# 8085  September  2016
# 8086  September  2016
# 8093       July  2016
# 8095       June  2016
# 8097      April  2016
#
# [6216 rows x 19 columns]

# %%
df = df.drop(columns = 'FromTo',axis = 1)
df = df.drop(columns = 'Month Flown',axis = 1)
df = df.drop(columns = 'Route',axis = 1)

# %%
df
# Out:
#                   Name             Airline Type of Traveller           Class  \
# 0     Alison Soetantyo  Singapore Airlines      Solo Leisure  Business Class
# 1        Robert Watson  Singapore Airlines      Solo Leisure   Economy Class
# 2                S Han  Singapore Airlines    Family Leisure   Economy Class
# 3             D Laynes  Singapore Airlines      Solo Leisure   Economy Class
# 4            A Othman   Singapore Airlines    Family Leisure   Economy Class
# ...                ...                 ...               ...             ...
# 8085          G Nazano          Korean Air          Business  Business Class
# 8086        V Anderson          Korean Air      Solo Leisure   Economy Class
# 8093             F Lee          Korean Air      Solo Leisure   Economy Class
# 8095         N Vickers          Korean Air          Business   Economy Class
# 8097           C Clark          Korean Air          Business  Business Class
#
#       Seat Comfort  Staff Service  Food & Beverages  Inflight Entertainment  \
# 0                4              4                 4                       4
# 1                5              3                 4                       4
# 2                1              5                 2                       1
# 3                5              5                 5                       5
# 4                5              5                 5                       5
# ...            ...            ...               ...                     ...
# 8085             4              5                 3                       4
# 8086             4              5                 4                       4
# 8093             3              4                 5                       4
# 8095             5              4                 5                       3
# 8097             4              5                 5                       5
#
#       Value For Money  Overall Rating Recommended   Via       From  \
# 0                   4               9         yes  None    Jakarta
# 1                   1               3          no  None     Phuket
# 2                   5              10         yes  None  Siem Reap
# 3                   5              10         yes  None  Singapore
# 4                   5              10         yes  None  Singapore
# ...               ...             ...         ...   ...        ...
# 8085                1               1          no   ICN        JFK
# 8086                5              10         yes  None        SFO
# 8093                3               7         yes   ICN        SEA
# 8095                4               7         yes   ICN        BNE
# 8097                1               2          no  None        DPS
#
#                    To      Month  Year
# 0           Singapore   December  2023
# 1           Singapore   February  2024
# 2           Singapore   February  2024
# 3     London Heathrow   February  2024
# 4          Phnom Penh   February  2024
# ...               ...        ...   ...
# 8085              TAS  September  2016
# 8086              ICN  September  2016
# 8093              SIN       July  2016
# 8095              ULN       June  2016
# 8097              ICN      April  2016
#
# [6216 rows x 16 columns]

# %%
df.fillna('No', inplace=True)
df
# Out:
#                   Name             Airline Type of Traveller           Class  \
# 0     Alison Soetantyo  Singapore Airlines      Solo Leisure  Business Class
# 1        Robert Watson  Singapore Airlines      Solo Leisure   Economy Class
# 2                S Han  Singapore Airlines    Family Leisure   Economy Class
# 3             D Laynes  Singapore Airlines      Solo Leisure   Economy Class
# 4            A Othman   Singapore Airlines    Family Leisure   Economy Class
# ...                ...                 ...               ...             ...
# 8085          G Nazano          Korean Air          Business  Business Class
# 8086        V Anderson          Korean Air      Solo Leisure   Economy Class
# 8093             F Lee          Korean Air      Solo Leisure   Economy Class
# 8095         N Vickers          Korean Air          Business   Economy Class
# 8097           C Clark          Korean Air          Business  Business Class
#
#       Seat Comfort  Staff Service  Food & Beverages  Inflight Entertainment  \
# 0                4              4                 4                       4
# 1                5              3                 4                       4
# 2                1              5                 2                       1
# 3                5              5                 5                       5
# 4                5              5                 5                       5
# ...            ...            ...               ...                     ...
# 8085             4              5                 3                       4
# 8086             4              5                 4                       4
# 8093             3              4                 5                       4
# 8095             5              4                 5                       3
# 8097             4              5                 5                       5
#
#       Value For Money  Overall Rating Recommended  Via       From  \
# 0                   4               9         yes   No    Jakarta
# 1                   1               3          no   No     Phuket
# 2                   5              10         yes   No  Siem Reap
# 3                   5              10         yes   No  Singapore
# 4                   5              10         yes   No  Singapore
# ...               ...             ...         ...  ...        ...
# 8085                1               1          no  ICN        JFK
# 8086                5              10         yes   No        SFO
# 8093                3               7         yes  ICN        SEA
# 8095                4               7         yes  ICN        BNE
# 8097                1               2          no   No        DPS
#
#                    To      Month  Year
# 0           Singapore   December  2023
# 1           Singapore   February  2024
# 2           Singapore   February  2024
# 3     London Heathrow   February  2024
# 4          Phnom Penh   February  2024
# ...               ...        ...   ...
# 8085              TAS  September  2016
# 8086              ICN  September  2016
# 8093              SIN       July  2016
# 8095              ULN       June  2016
# 8097              ICN      April  2016
#
# [6216 rows x 16 columns]

# %%
df.to_csv('airlines.csv', index=False)
